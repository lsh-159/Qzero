# %%
from google.colab import drive
import os

drive.mount('/content/drive')

YourPATH = '/content/drive/MyDrive/Colab Notebooks/YAI-quoridor'
os.chdir(YourPATH)
# !dir
# Out:
# Mounted at /content/drive
# data	      log     Run_Qzero.ipynb  TODO.ipynb
# errorlog.txt  models  src	       Visualize_Games.ipynb

# %%
# !cat /proc/meminfo
# !cat /proc/cpuinfo
# !nvidia-smi

# %%
# !cp -r -f '/content/drive/MyDrive/Colab Notebooks/YAI-quoridor/src/cpp' '/content'

# %cd /content/cpp
# !python setup.py build_ext --inplace

os.chdir(YourPATH)

# !pip install torchcontrib
# %cd '/content/drive/MyDrive/Colab Notebooks/YAI-quoridor'

# %% [markdown]
# ## **SelfPlay Cell**

# %%
# !python src/SelfPlay.py         # PUCT with dir noise <= r move
# Out:
# Traceback (most recent call last):
#   File "src/SelfPlay.py", line 32, in <module>
#     from CyPlayer import *
#   File "/content/drive/MyDrive/Colab Notebooks/YAI-quoridor/src/CyPlayer.py", line 78
#     StatKeys = ['rootchild', 'pp_h', 'Narr_h', 'V_h', 'VAux_h', 'Q_h', 'B_h', 'D_h'.' history']
#                                                                                     ^
# SyntaxError: invalid syntax

# %%
function ClickConnect(){
console.log("Working"); 
document.querySelector("colab-toolbar-button").click() 
}setInterval(ClickConnect, 1800000)

# %%
# !python src/CyTrainer.py
# Out:
# Running CyTrainer.py in cwd : /content/drive/MyDrive/Colab Notebooks/YAI-quoridor
#
# ...
# trainer >> __init__ : Qzero Training         batchsize = 1024      DEVICE : cpu
# ...
# Trainer >> Unlock Mutex_Train Success, 2023-1-9 14:28:8
# Trainer >> Lock Mutex_Train Success, 2023-1-9 14:28:8
# Trainer >> Current total 953078samples / new samples : 953078 (0 hit)
# Trainer >> Sufficient Data colleted that are not trained : 953078 >= 250000
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Updater >> Training starts... 	calling self.train()
# Trainer >> Loading the most recent model in ./models.. dual_net[b5c64]-00028
# Trainer >> Loading the Board_Dataset...
#
#
# ...
# board_dataset __init__ : checking ./data
# ...
# Train Dataset >> Detecting Hit-not sufficient data ...		complete. Detected 475 packs (953078 samples)
# Train Dataset >> Since 953078 samples >= 300000,  total 4 epoches will be processed
# ...

# %%
# !python src/CyArena.py

# %%
# cat /dev/null > ./log/all.log           # all.log 초기화
# print(open('./log/all.log').read())     # all.log 읽기
